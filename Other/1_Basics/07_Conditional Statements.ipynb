# %%
if True:
  print("What's up Data Nerds")

# %%
# Skill required for job posting
 job_skill = "SQL"

 # Applicant skill
 applicant_skill = "SQL"

# %%
if job_skill == applicant_skill:
  print("Skills Match!")

# %%
job_skill = "SQL"
applicant_skill = "Python"
years_experience = 3

if job_skill == applicant_skill:
  print("Skills Match!")
elif years_experience >= 5:
  print("Enough Experience; No SQL")
elif applicant_skill == "Python":
  pass
else:

# %%
if job_skill == aplicant_skill:
  pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ed37a13145e> in <cell line: 0>()
# ----> 1 if job_skill == aplicant_skill:
#       2   pass
#
# NameError: name 'job_skill' is not defined

# %% [markdown]
# # Problems

# %%
# Determine Python Experience

python_experience = 3

# %%
if python_experience == 3:
  print("Adequate Python Experience")
# Out:
# Adequate Python Experience

# %%
# Determine Job Skill Level

tools_known = 3

# %%
# Determine Job Title

job_experience = 5
sql_experience = 3

# %%
if job_experience >= 4 & sql_experience < 2:
  print("Enough Job Experience; No SQL")
elif sql_experience >= 2 & job_experience < 4:
  print("Enough SQL experience; Not enough job experience")
elif job_experience >= 4 & sql_experience >= 2:
  print("Good Enough")
else:
  print("Not enough")
# Out:
# Enough Job Experience; No SQL
