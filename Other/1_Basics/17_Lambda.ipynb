# %%
mul_two = lambda x: x*2

# %%
mul_two(3)
# Out:
# 6

# %%
(lambda x, y: x*2 + y)(3, 6)
# Out:
# 12

# %%
salary_list = [100000, 200000, 150000, 120000, 80000, 750000]

# Calculate total_salary of base_salary * (1 + bonus_rate)
# def calculate_salary(base_salary, bonus_rate=.1):

#  return base_salary * (1 + bonus_rate)

total_salary_list = [salary * 1.1 for salary in salary_list]

total_salary_list
# Out:
# [110000.00000000001,
#  220000.00000000003,
#  165000.0,
#  132000.0,
#  88000.0,
#  825000.0000000001]

# %%
jobs_data = [
    {'job_title': 'Data Scienctist', 'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst', 'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'Tensor Flow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
list(filter(lambda job: job['remote'] and "Python" in job['job_skills'], jobs_data))
# Out:
# [{'job_title': 'Data Scienctist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'Tensor Flow', 'Keras'],
#   'remote': True}]

# %%
# Define a Lambda function to add two numbers
add = lambda x, y: x + y

# %%
# Use the Lambda function to add two numbers
result1 = add(3, 5)
result1
# Out:
# 8

# %%
salary_list = [100000, 200000, 150000, 120000, 80000, 750000]

# Calculate total_salary of base saalry * (1 + bonus_rate)
def calculate_salary(base_salary, bonus_rate=.1):
  return round(base_salary * (1 + bonus_rate), 2)

total_salary_list = [calculate_salary(salary) for salary in salary_list]

total_salary_list
# Out:
# [110000.0, 220000.0, 165000.0, 132000.0, 88000.0, 825000.0]

# %%
total_salary_list = [round((lambda x: x * (1.1))(salary),2) for salary in salary_list]

total_salary_list
# Out:
# [110000.0, 220000.0, 165000.0, 132000.0, 88000.0, 825000.0]

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
help(filter)
# Out:
# Help on class filter in module builtins:
#
# class filter(object)
#  |  filter(function or None, iterable) --> filter object
#  |
#  |  Return an iterator yielding those items of iterable for which function(item)
#  |  is true. If function is None, return the items that are true.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
# First let's just test out and only filter jobs that are remote

list(filter(lambda job: job ['remote'], jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True},
#  {'job_title': 'Software Developer',
#   'job_skills': ['Java', 'C++'],
#   'remote': True}]

# %%
# Define a Lambda function for filtering jobs that require Python and are remote
filter_criteria = lambda job: 'Python' in job['job_skills'] and job['remote']

# Apply the filter
python_remote_jobs = list(filter(filter_criteria, jobs_data))

# Display the filtered job listings
for job in python_remote_jobs:
  print(job)
# Out:
# {'job_title': 'Data Scientist', 'job_skills': ['Python', 'Machine Learning'], 'remote': True}
# {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True}

# %% [markdown]
# # Problems

# %%
# Calculate Average Salary

salaries = [95000, 120000, 105000, 90000, 130000]

avg_salary = lambda x: sum(x) / len(x)

avg_salary(salaries)
# Out:
# 108000.0

# %%
# Filter Job Titles

job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']

data_jobs = list(filter(lambda x: 'Data' in x, job_titles))

data_jobs
# Out:
# ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %%
# Filter Remote Python Jobs

job_postings = [
    {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
    {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False},
    {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True},
    {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True}
]

# %%
filter_criteria = lambda x: x['remote'] and 'Python' in x['skills']

python_remote_jobs = list(filter(filter_criteria, job_postings))

for job in python_remote_jobs:
  print(job)
# Out:
# {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True}
# {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True}

# %%
# Calculate average age

ages = [23, 45, 30, 35, 40]

# %%
avg_age = lambda x: sum(x) / len(x)

avg_age(ages)
# Out:
# 34.6

# %%
# Filter names that start with 'A'

names = ['Alice', 'Bob', 'Amanda', 'Charlie', 'Andrew']

# %%
a_names = list(filter(lambda x: 'A' in x, names))

for name in a_names:
  print(name)
# Out:
# Alice
# Amanda
# Andrew

# %%
# Filter online courses that require python

courses = [
    {'name': 'Data Science Bootcamp', 'skills': ['Python', 'SQL'], 'online': True},
    {'name': 'Business Analytics', 'skills': ['Excel', 'SQL'], 'online': False},
    {'name': 'Machine Learning Advanced', 'skills': ['Python', 'TensorFlow'], 'online': True},
    {'name': 'Software Development', 'skills': ['Java', 'C++'], 'online': True}
]

# %%
filter_conditions = lambda x: x['online'] and 'Python' in x['skills']

python_online_courses = list(filter(filter_conditions, courses))

for course in python_online_courses:
  print(course)
# Out:
# {'name': 'Data Science Bootcamp', 'skills': ['Python', 'SQL'], 'online': True}
# {'name': 'Machine Learning Advanced', 'skills': ['Python', 'TensorFlow'], 'online': True}
