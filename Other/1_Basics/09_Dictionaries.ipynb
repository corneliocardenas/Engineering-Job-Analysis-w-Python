# %% [markdown]
# # Dictionaries

# %%
# Define a dictionary of data science skills

job_type_skills = {
    "database": "postgresql",
    "language": "python",
    "library": "pandas"
}

job_type_skills
# Out:
# {'database': 'postgresql', 'language': 'python', 'library': 'pandas'}

# %%
job_type_skills["language"]
# Out:
# 'python'

# %%
job_type_skills.keys()
# Out:
# dict_keys(['database', 'language', 'library'])

# %%
job_type_skills.get("analytics", "not found")
# Out:
# 'not found'

# %%
job_type_skills.values()
# Out:
# dict_values(['postgresql', 'python', 'pandas'])

# %%
job_type_skills.items()
# Out:
# dict_items([('database', 'postgresql'), ('language', 'python'), ('library', 'pandas')])

# %%
job_type_skills.pop("library")

job_type_skills
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-1e27304effba> in <cell line: 0>()
# ----> 1 job_type_skills.pop("library")
#       2
#       3 job_type_skills
#
# KeyError: 'library'

# %%
job_type_skills
# Out:
# {'database': 'postgresql', 'language': 'python'}

# %%
job_type_skills["framework"] = "flask"

job_type_skills
# Out:
# {'database': 'postgresql', 'language': 'python', 'framework': 'flask'}

# %%
job_type_skills.update({"cloud": "google cloud", "version_control": "git"})

job_type_skills
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'framework': 'flask',
#  'cloud': 'google cloud',
#  'version_control': 'git'}

# %%
job_type_skills.update({"language": ["python", "r"]})

job_type_skills
# Out:
# {'database': 'postgresql',
#  'language': ['python', 'r'],
#  'framework': 'flask',
#  'cloud': 'google cloud',
#  'version_control': 'git'}

# %% [markdown]
# # Problems

# %%
# Code Needed

job_postings = {"Data Scientist": 120, "Data Analyst": 80, "Machine Learning Engineer": 50}

# %%
job_postings
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}

# %%
# Add Job Role

job_postings = {"Data Scientis": 120, "Data Analyst": 80, "Machine Learning Engineer": 50}

# %%
job_postings["Data Engineer"] = 110

# %%
job_postings
# Out:
# {'Data Scientis': 120,
#  'Data Analyst': 80,
#  'Machine Learning Engineer': 50,
#  'Data Engineer': 110}

# %%
# Remove Job Role

job_postings = {"Data Scientist": 120, "Data Analyst": 80, "Machine Learning Enegineer": 50}

# %%
job_postings.pop("Machine Learning Enegineer")
# Out:
# 50

# %%
job_postings
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80}

# %%
# Merge Dictionaries

job_postings1 = {"Data Scientist": 120, "Data Analyst": 80}
job_postings2 = {"Machine Learning Engineer": 50, "AI Specialist": 30}

# %%
job_postings1.update(job_postings2)

# %%
job_postings1
# Out:
# {'Data Scientist': 120,
#  'Data Analyst': 80,
#  'Machine Learning Engineer': 50,
#  'AI Specialist': 30}

# %%
# Create Nested Dictionary

job_postings = {"Data Jobs": {"Data Scientist": 120, "Data Analyst": 80}}

# %%
job_postings
# Out:
# {'Data Jobs': {'Data Scientist': 120, 'Data Analyst': 80}}

# %%
job_postings.values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-953d68beb87f> in <cell line: 0>()
# ----> 1 job_postings.values()
#
# NameError: name 'job_postings' is not defined
