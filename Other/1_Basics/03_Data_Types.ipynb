# %%
total_salary = 110000
bonus_salary = 10000

# %%
type(total_salary)
# Out:
# int

# %%
base_salary = total_salary - bonus_salary

base_salary
# Out:
# 100000

# %%
job_title = "Data Analys"
remove_word = "Data"

# %%
type(job_title)
# Out:
# str

# %%
final_title = job_title - remove_word
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f7a95a7421b7> in <cell line: 0>()
# ----> 1 final_title = job_title - remove_word
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
text_str = "Data Nerd!"
numeric_int = 42
numeric_float = 3.1416
numeric_complex = 1 + 2j
sequence_list = [1, 2, 3]
sequence_tuple = (1, 2, 3)
sequence_range = range(10)
mapping_dict = {"key": "value"}
set_set = {1, 2, 3}
set_frozenset = frozenset([1, 2, 3])
boolean_bool = True
binary_bytes = b"Data"
binary_bytearray = bytearray(5)
binary_memoryview = memoryview(b"Data")
none_noneType = None

# %%
print(type(text_str), "common")
print(type(numeric_int), "common")
print(type(numeric_float), "common")
print(type(numeric_complex))
print(type(sequence_list), "common")
print(type(sequence_tuple), "common")
print(type(sequence_range))
print(type(mapping_dict), "common")
print(type(set_set), "common")
print(type(set_frozenset))
print(type(boolean_bool))
print(type(binary_bytes))
print(type(binary_bytearray))
print(type(binary_memoryview))
print(type(none_noneType))
# Out:
# <class 'str'> common
# <class 'int'> common
# <class 'float'> common
# <class 'complex'>
# <class 'list'> common
# <class 'tuple'> common
# <class 'range'>
# <class 'dict'> common
# <class 'set'> common
# <class 'frozenset'>
# <class 'bool'>
# <class 'bytes'>
# <class 'bytearray'>
# <class 'memoryview'>
# <class 'NoneType'>

# %%
print(isinstance(text_str, float))
print(isinstance(binary_bytearray, bytearray))
# Out:
# False
# True

# %%
help(isinstance)
# Out:
# Help on built-in function isinstance in module builtins:
#
# isinstance(obj, class_or_tuple, /)
#     Return whether an object is an instance of a class or of a subclass thereof.
#
#     A tuple, as in ``isinstance(x, (A, B, ...))``, may be given as the target to
#     check against. This is equivalent to ``isinstance(x, A) or isinstance(x, B)
#     or ...`` etc.

# %%
help(str)
# Out:
# Welcome to Python 3.11's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.11/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
str("Hello World")
# Out:
# 'Hello World'

# %%
int(20)
# Out:
# 20

# %%
float(20.5)
# Out:
# 20.5

# %%
complex(1j)
# Out:
# 1j

# %%
list(("apple", "banana", "cherry"))
# Out:
# ['apple', 'banana', 'cherry']

# %%
tuple(("apple", "banana", "cherry"))
# Out:
# ('apple', 'banana', 'cherry')

# %%
range(6)
# Out:
# range(0, 6)

# %%
dict(name="John", age=36)
# Out:
# {'name': 'John', 'age': 36}

# %%
set(("apple", "banana", "cherry"))
# Out:
# {'apple', 'banana', 'cherry'}

# %%
frozenset(("apple", "banana", "cherry"))
# Out:
# frozenset({'apple', 'banana', 'cherry'})

# %%
bool(5)
# Out:
# True

# %%
bytes(5)
# Out:
# b'\x00\x00\x00\x00\x00'

# %%
bytearray(5)
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')

# %%
memoryview(bytes(5))

# %%
company_name = str("Data Nerd, Inc.")

# %%
job_id = 102

type(job_id)
# Out:
# int

# %%
job_id = float(102)

print("Job ID:         ", job_id)
print("Type of Job ID: ", type(job_id))
# Out:
# Job ID:          102.0
# Type of Job ID:  <class 'float'>

# %% [markdown]
# # Check Data Type

# %%
job_title = "Data Scientist"

# %%
type(job_title)
# Out:
# str

# %% [markdown]
# # Check Float Type

# %%
salary = 85000.50

# %%
type(salary)
# Out:
# float

# %% [markdown]
# # Convert to Integer

# %%
salary_rate = 120000.75

# %%
print(int(salary_rate))
# Out:
# 120000

# %% [markdown]
# # Check String Type

# %%
company_name = "DataWiz Inc."

# %%
type(company_name)
# Out:
# str
