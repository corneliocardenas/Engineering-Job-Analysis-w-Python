# %%
base_salary = 100000

# %%
bonus_rate = 0.1

total_salary = base_salary * (1 + bonus_rate)

# %%
total_salary # Calling a Variable

base_salary # Can't call 2 variables in the same cell
# Out:
# 100000

# %%
job_id = 101
company_name = "DataWiz Inc."
job_title = "Data Analyst"
job_salary = 125000
job_work_from_home = True

# %%
print("Job ID:      ", job_id)
print("Company Name:", company_name)
print("Job Title:   ", job_title)
print("Salary:      ", job_salary)
print("WFH:         ", job_work_from_home)
# Out:
# Job ID:       101
# Company Name: DataWiz Inc.
# Job Title:    Data Analyst
# Salary:       125000
# WFH:          True

# %%
job_title = "Data Analyst"
job_salary = 90000
my_print_function = print

# %%
my_print_function(job_title, job_salary)
# Out:
# Data Analyst 90000

# %%
lukes_job = job_title

lukes_job
# Out:
# 'Data Analyst'

# %%
job_title1 = "Data Analyst"
job_title2 = "Data Analyst"

id(job_title1), id(job_title2)
# Out:
# (134355617640816, 134355618085296)

# %%
print("What's up, Data Nerds!")
# Out:
# What's up, Data Nerds!

# %%
def greet():
  return "What's up, Data Nerds!"

# %%
greet()
# Out:
# "What's up, Data Nerds!"

# %%
def display_info(title, location, salary):
  return print(f"JOB:       {title}\nLOCATION:  {location}\nSALARY:    ${salary:,.0f}")

# %%
job_title = "Data Analyst"
job_location = "United States"
job_salary = 90000

display_info(job_title, job_location, job_salary)
# Out:
# JOB:       Data Analyst
# LOCATION:  United States
# SALARY:    $90,000

# %%
def player_specs(name, strength, speed, iq):
  return print(f"NAME:     {name}\nSTRENGTH: {strenght}\nSPEED     {speed}\nIQ:       {iq}")

# %%
name = "Cornelio"
strenght = 7
speed =  8
iq = 6

player_specs(name, strenght, speed, iq)
# Out:
# NAME:     Cornelio
# STRENGTH: 7
# SPEED     8
# IQ:       6

# %%
class JobPost:
    def __init__(self, title, location, salary):
        self.title = title  # Attribute
        self.location = location  # Attribute
        self.salary = salary  # Attribute

    def display_info(self):
        return print(f"JOB:       {self.title}\nLOCATION:  {self.location}\nSALARY:    ${self.salary:,.0f}")

# %% [markdown]
# # Example of Object

# %%
"Cornelio" # This is an object

20 # This too

# Everything is an object
# Out:
# 20

# %% [markdown]
# # Define Variable

# %%
name = "Cornelio"
age = 20

# %% [markdown]
# # Define Function

# %%
def upper(name):
  return print(f"Name in Upper: {name.upper()}")

# %%
name = "Rommel"
upper(name)
# Out:
# Name in Upper: ROMMEL

# %% [markdown]
# # Define Class

# %%
class Characters:
  def __init__(self, name, age, strength):
    self.name = name
    self.age = age
    self.strength = strength

  def display_stats(self):
    return print(f"Name:     {self.name}\nAge:      {self.age}\nStrength: {self.strength:,.0f}")

# %%
Characters
# Out:
# __main__.Characters

# %% [markdown]
# # Call Method

# %%
character = Characters("Cornelio", 20, 20)

character.display_stats()
# Out:
# Name:     Cornelio
# Age:      20
# Strength: 20

# %% [markdown]
# # Example of Attribute

# %%
class Characters:
  def __init__(self, name, age, strength):
    self.name = name # Attributes
    self.age = age # Attributes
    self.strength = strength # Attributes

  def display_stats(self):
    return print(f"Name:     {self.name}\nAge:    {self.age}\nStrength:   {self.strength:,.0f}")

# %% [markdown]
# # Problems
#
# 1. Job Postings Count
# 2. Job Information
# 3. Calculate Total Compensation
# 4. Calculate Monthly Salary
# 5. Calculate Total Compensation with Bonus

# %%
job_postings_count = 32000

# %%
job_id = 102
company_name = "Corning"
job_title = "Analista de Datos"
job_salary = 2
job_work_from_home = False

# %%
print("Job ID:       ", job_id)
print("Company Name: ", company_name)
print("Job Title:    ", job_title)
print("Salary:       ", job_salary)
print("WFH:          ", job_work_from_home)
# Out:
# Job ID:        102
# Company Name:  Corning
# Job Title:     Analista de Datos
# Salary:        2
# WFH:           False

# %%
base_salary = 97000

bonus_rate = 0.1

total_compensation = base_salary * (1 + bonus_rate)

# %%
total_compensation
# Out:
# 106700.00000000001

# %%
monthly_salary = round(float(total_compensation), 2) / 12

round(monthly_salary,2)
# Out:
# 8891.67

# %%
total_compensation
# Out:
# 106700.00000000001
