# %% [markdown]
# # Lists

# %%
my_list = [1, "python", [2, "sql"]]

my_list
# Out:
# [1, 'python', [2, 'sql']]

# %%
job_skills = ["sql", "tableau", "excel"]

# %%
job_skills.append("python")

# %%
job_skills
# Out:
# ['sql', 'tableau', 'excel', 'python']

# %%
job_skills.remove("tableau")

# %%
job_skills
# Out:
# ['sql', 'excel', 'python']

# %%
len("python")
# Out:
# 6

# %%
len(job_skills)
# Out:
# 3

# %%
job_skills
# Out:
# ['sql', 'excel', 'python']

# %%
job_skills[2]
# Out:
# 'python'

# %%
job_skills.insert(2, "tableau")

# %%
job_skills
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills.pop(3)
# Out:
# 'python'

# %%
job_skills
# Out:
# ['sql', 'excel', 'tableau']

# %%
job_skills.insert(3, "python")

# %%
job_skills
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills.pop()
# Out:
# 'tableau'

# %%
job_skills
# Out:
# ['sql', 'excel']

# %%
job_skills = ["sql", "excel", "python"]

# %%
job_skills[:1]
# Out:
# ['sql']

# %%
job_skills[::3]
# Out:
# ['sql']

# %%
luke_skills = ["python", "bigquery", "r"]
kelly_skills = ["python", "sql", "looker"]

all_skills = luke_skills + kelly_skills

all_skills
# Out:
# ['python', 'bigquery', 'r', 'python', 'sql', 'looker']

# %%
all_skills[::2]
# Out:
# ['python', 'r', 'sql']

# %%
all_skills[5:]
# Out:
# ['looker']

# %%
all_skills[-2:]
# Out:
# ['sql', 'looker']

# %%
job_skills = ["python", "excel", "sql", "looker"]

# %%
skill1, skill2, skill3 = job_skills

# %%
print(skill1)
print(skill2)
print(skill3)
# Out:
# python
# excel
# sql

# %%
skill_concerned, *skill_dont_care = job_skills

# %%
print(skill_concerned)
print(skill_dont_care)
# Out:
# python
# ['excel', 'sql', 'looker']

# %% [markdown]
# # Problems

# %%
# Access Second Job Title

job_titles = ["Data Scientist", "Data Analyst", "Machine Learning Engineer"]

# %%
job_titles[1]
# Out:
# 'Data Analyst'

# %%
# Change Third Job Title

job_titles = ["Data Scientist", "Data Analyst", "Machine Learning Engineer"]

# %%
job_titles[2] = "ML Engineer"

# %%
job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'ML Engineer']

# %%
# Slice Job Titles List

job_titles = ["Data Scientist", "Data Analyst", "Machine Learning Engineer", "Data Engineer"]

# %%
job1, job2, job3, job4 = job_titles

# %%
print(job1)
print(job2)
print(job3)
print(job4)
# Out:
# Data Scientist
# Data Analyst
# Machine Learning Engineer
# Data Engineer

# %%
# Append Job Title

job_titles = ["Data Scientist", "Data Analyst", "Machine Learning Engineer"]

# %%
job_titles.append("Data Engineer")

# %%
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Data Engineer']

# %%
# Insert Job Title

# %%
job_titles = ["Data Scientist", "Data Analyst", "Machines Learning Engineer"]

# %%
job_titles.insert(1, "Senior Data Analyst")

# %%
job_titles
# Out:
# ['Data Scientist',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Machines Learning Engineer']
