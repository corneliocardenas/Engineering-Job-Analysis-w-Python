# %%
# Importing libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# Count Trye and False values
work_from_home = df['job_work_from_home'].value_counts()

# %%
# Plotting the pie chart
plt.figure(figsize=(6,6))
plt.pie(work_from_home, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Work from Home Status')
plt.show()

# %%
# Count True and False values
job_no_degree = df['job_no_degree_mention'].value_counts()

# %%
job_health_insurance = df['job_health_insurance'].value_counts()

# %%
# Set up the matplotlib figure
fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

# Data Analyst Salaries
plt.subplot(1, 3, 1)
plt.pie(work_from_home, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Work from Home Offered')

# Job No Degree
plt.subplot(1, 3, 2)
plt.pie(job_no_degree, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Degree Requirement')

# Job Health Insurance
plt.subplot(1, 3, 3)
plt.pie(job_health_insurance, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Health Insurance Offered')

plt.tight_layout()
plt.show()

# %%
# Rewrite the above with a for loop
dict_column = {
    'job_work_from_home': 'Work from Home Offered',
    'job_no_degree_mention': 'Degree Requirements',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_incehs = ((12, 5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.suptitle('Benefit Analysis for Data Jobs', fontsize=16)
plt.tight_layout()
plt.show()

# %%
dict_column.items()
# Out:
# dict_items([('job_work_from_home', 'Work from Home Offered'), ('job_no_degree_mention', 'Degree Requirements'), ('job_health_insurance', 'Health Insurance Offered')])

# %% [markdown]
# # Problems

# %%
# Health Insurance Pie Chart
health_insurance = df['job_health_insurance'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(health_insurance, labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
plt.title('Offered Health Insurance')
plt.show()

# %%
# Job Schedule Distribution
job_schedules = df['job_schedule_type'].value_counts()
main_schedules = job_schedules.loc[['Full-time', 'Contractor', 'Internship', 'Part-time']]

plt.figure(figsize=(7,7))
plt.pie(main_schedules, labels=main_schedules.index, autopct='%1.1f%%', startangle=90)
plt.title('Job Schedules Distribution')
plt.axis('equal')
plt.show()

# %%
# Degree Mentioned Pie Chart
degree_mentioned = df['job_no_degree_mention'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(degree_mentioned, labels=['True', 'False'], autopct='%1.1f%%', startangle=90)
plt.title('Degree Mentioned')
plt.show()

# %%
degree_mentioned
# Out:
# job_no_degree_mention
# False    544965
# True     240776
# Name: count, dtype: int64
