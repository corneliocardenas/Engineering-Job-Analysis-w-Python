# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.groupby('job_title_short')['salary_year_avg'].median().head(20)
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.iloc[[2,3],[15,16]]
# Out:
#                                           job_skills  \
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
#
#                                      job_type_skills
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...

# %%
df.iloc[:10]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df.iloc[:, :5]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.loc[0]
# Out:
# job_title_short                                       Senior Data Engineer
# job_title                Senior Clinical Data Engineer / Principal Clin...
# job_location                                                 Watertown, CT
# job_via                                                    via Work Nearby
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                       Texas, United States
# job_posted_date                                        2023-06-16 13:44:15
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# ...

# %%
df.loc[0:9, ['job_skills', 'job_type_skills']]
# Out:
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7  ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                ['excel', 'powerpoint', 'power bi']
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# ...

# %%
df.loc[10:20, 'job_title_short':'job_work_from_home']
# Out:
#          job_title_short                                    job_title  \
# 10         Data Engineer         Erfahrene*r Data Engineer*in (m/w/d)
# 11         Data Engineer                                Data Engineer
# 12          Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13  Senior Data Engineer                         Senior Data Engineer
# 14         Data Engineer                                Data Engineer
# 15         Data Engineer                                Data Engineer
# 16         Data Engineer                            Big Data Engineer
# 17        Data Scientist                       Data Science Team Lead
# 18          Data Analyst                                 Data Analyst
# 19        Data Scientist                               Data Scientist
# 20        Data Scientist                               Data Scientist
#
#                                        job_location  \
# 10                               Basel, Switzerland
# ...

# %%
df.loc[:12]
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1           Data Analyst                                       Data Analyst
# 2          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4          Data Engineer                             Data Engineer- Sr Jobs
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7          Data Engineer                                      Data Engineer
# 8       Business Analyst           Technology & Operations Business Analyst
# 9         Data Scientist                                  Data Scientist II
# 10         Data Engineer               Erfahrene*r Data Engineer*in (m/w/d)
# ...

# %%
df.loc[:, 'job_title_short':'job_schedule_type']
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %% [markdown]
# # Problems

# %%
# Select 5 Rows witg .iloc()

df.iloc[:5]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# Get Rows and Columns with .loc()

df.loc[:,:]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# First 15 Rows in US

df.loc[df['job_country'] == 'United States'].head(15)
# Out:
#          job_title_short                                          job_title  \
# 0   Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 3          Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5          Data Engineer                                  GCP Data Engineer
# 6   Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 9         Data Scientist                                  Data Scientist II
# 11         Data Engineer                                      Data Engineer
# 13  Senior Data Engineer                               Senior Data Engineer
# 17        Data Scientist                             Data Science Team Lead
# 26         Data Engineer                                      Data Engineer
# 27         Data Engineer  Principal Data Engineer (Lead), Knowledge Grap...
# 30  Senior Data Engineer     Senior Data Engineer (Work from home Eligible)
# ...

# %%
# Filter by Date

df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df['job_posted_month']
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_month, Length: 785741, dtype: int32

# %%
df.loc[df['job_posted_month'] == 1].head(15)
# Out:
#            job_title_short                            job_title  \
# 1             Data Analyst                         Data Analyst
# 20          Data Scientist                       Data Scientist
# 39           Data Engineer                        Data Engineer
# 53           Data Engineer                        Data Engineer
# 55          Data Scientist                       Data Scientist
# 56   Senior Data Scientist      Principal Statistical Scientist
# 58   Senior Data Scientist                Senior Data Scientist
# 60        Business Analyst         Business Intelligence Intern
# 61           Data Engineer                        Data Engineer
# 69       Software Engineer  Software Engineer in Data Warehouse
# 84          Data Scientist                         Data Science
# 91          Data Scientist                       Data Scientist
# 108          Data Engineer   Chapter Lead Data Engineers Poland
# 131          Data Engineer                  Cloud Data Engineer
# ...
