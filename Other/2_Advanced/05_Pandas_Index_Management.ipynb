# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#              job_title_short                         job_title  \
# 724299        Data Scientist                Jr. Data Scientist
# 34305       Business Analyst           Human Resources Analyst
# 528439     Software Engineer                   DevOps engineer
# 177026  Senior Data Engineer          SAP Senior Data Engineer
# 621935          Data Analyst  Intermediate/Senior Data Analyst
#
#                                              job_location  \
# 724299                                           Anywhere
# 34305   Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 528439                               Utrecht, Netherlands
# 177026                Treviso, Province of Treviso, Italy
# 621935                                           Anywhere
#
#                        job_via job_schedule_type  job_work_from_home  \
# 724299            via The Muse         Full-time                True
# 34305       via BeBee Malaysia              None               False
# ...

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.tail(5)
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
df.index.name = 'job_index'

# %%
df.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa = df[df['job_country'] == 'United States']
df_usa.reset_index(inplace=True)

df_usa
# Out:
#         job_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_usa.set_index('job_index', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16652\3286616987.py in ?()
# ----> 1 df_usa.set_index('job_index', inplace=True)
#       2 df_usa
#
# c:\Users\joaqu\anaconda3\envs\python_course\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['job_index'] are in the columns"

# %%
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
median_pivot = df_usa.pivot_table(
    values='salary_year_avg',
    index='job_title_short',
    aggfunc=['median', 'min', 'max']
)

# %%
median_pivot.sort_values(by=('median', 'salary_year_avg'), ascending=False)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155000.0         55000.0        475000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Software Engineer                130000.0         48982.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Business Analyst                  90000.0         35000.0        387460.0
# Data Analyst                      90000.0         25000.0        375000.0

# %%
median_pivot.sort_index(inplace=True)

# %%
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  90000.0         35000.0        387460.0
# Cloud Engineer                   116100.0         42000.0        221844.0
# Data Analyst                      90000.0         25000.0        375000.0
# Data Engineer                    125000.0         23496.0        525000.0
# Data Scientist                   130000.0         30000.0        960000.0
# Machine Learning Engineer        150000.0         44408.5        315000.0
# Senior Data Analyst              110000.0         35360.0        425000.0
# Senior Data Engineer             150000.0         45000.0        375000.0
# Senior Data Scientist            155000.0         55000.0        475000.0
# Software Engineer                130000.0         48982.0        375000.0

# %%
df.sample(5)
# Out:
#        job_title_short                                          job_title  \
# 99759     Data Analyst                 Business Intelligence Data Analyst
# 330930   Data Engineer                         Data engineer eventual gye
# 74267     Data Analyst  Data Analyst for Health & Safety Team Intern -...
# 102259  Data Scientist  Data Scientist / Data Engineer-German speaker-...
# 748742  Data Scientist                   Data Scientist (Multiple Levels)
#
#                   job_location                    job_via job_schedule_type  \
# 99759               Austin, TX  via Texas Jobs - Tarta.ai         Full-time
# 330930                 Ecuador               via Sercanto         Full-time
# 74267            Paris, France            via Recruit.net        Internship
# 102259                 Germany            via Recruit.net         Full-time
# 748742  Annapolis Junction, MD            via SimplyHired         Full-time
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.index.name

# %%
df.index.name = 'job_index'

# %%
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Out:
#              job_title_short  \
# job_index
# 562151          Data Analyst
# 731699        Data Scientist
# 318476     Software Engineer
#
#                                                    job_title     job_location  \
# job_index
# 562151                               alternance data analyst  Bobigny, France
# 731699                                        Data Scientist         Anywhere
# 318476     Software Development Engineer, OpenSearch Mach...  Dublin, Ireland
#
#                    job_via job_schedule_type  job_work_from_home  \
# job_index
# 562151           via BeBee         Full-time               False
# 731699        via LinkedIn        Contractor                True
# 318476     via Trabajo.org         Full-time               False
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 562151                      France 2023-09-30 04:29:16                  False
# ...

# %%
median_pivot = df.pivot_table(
    values='salary_year_avg',
    index='job_title_short',
    aggfunc='median'
)

median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
index_name = median_pivot.index.name
index_name
# Out:
# 'job_title_short'

# %%
index_dtype = median_pivot.index.dtype
index_dtype
# Out:
# dtype('O')

# %%
df_usa = df[df['job_country'] == 'United States']

df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
df_usa.index
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %%
df_usa.reset_index(inplace=True)
df_usa.head()
# Out:
#    job_index       job_title_short  \
# 0          0  Senior Data Engineer
# 1          3         Data Engineer
# 2          5         Data Engineer
# 3          6  Senior Data Engineer
# 4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# ...

# %%
df_usa.index
# Out:
# RangeIndex(start=0, stop=206292, step=1)

# %%
median_pivot.reset_index(inplace=True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
df_usa.set_index('job_index', inplace=True)

df_usa.head()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# ...

# %%
median_pivot.set_index('job_title_short', inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
median_pivot.sort_index(inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %% [markdown]
# # Problems

# %%
# Set Index and Display Rows
df_index = df
df_index.index.name = 'job_index'
df_index.head(3)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                            job_location           job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT   via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2                       Berlin, Germany      via LinkedIn         Full-time
#
#            job_work_from_home       search_location     job_posted_date  \
# job_index
# 0                       False  Texas, United States 2023-06-16 13:44:15
# 1                       False                Mexico 2023-01-14 13:18:07
# ...

# %%
# Reset Index and Drop Existing
df_usa = df[df['job_country'] == 'United States']
df_usa.reset_index(inplace=True)
df_usa.drop(columns=['job_index'], inplace=True)
df_usa.head()
# Out:
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_16652\39377089.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa.drop(columns=['job_index'], inplace=True)
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2         Data Engineer                                  GCP Data Engineer
# 3  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 4        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# ...

# %%
df_usa = df[df['job_country'] == 'United States']
df_usa.reset_index(drop=True, inplace=True)
df_usa.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2         Data Engineer                                  GCP Data Engineer
# 3  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 4        Data Scientist                                  Data Scientist II
#
#       job_location            job_via         job_schedule_type  \
# 0    Watertown, CT    via Work Nearby                 Full-time
# 1  San Antonio, TX  via Diversity.com                 Full-time
# 2         Anywhere   via ZipRecruiter  Contractor and Temp work
# 3     Dearborn, MI       via LinkedIn                 Full-time
# 4         Anywhere   via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# ...

# %%
# Sort Index
df_usa.sort_index(inplace=True, ascending=False)
df_usa.head()
# Out:
# C:\Users\joaqu\AppData\Local\Temp\ipykernel_16652\2452688283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa.sort_index(inplace=True, ascending=False)
#        job_title_short                                  job_title  \
# 206291    Data Analyst  Expert Business Data Analyst - Now Hiring
# 206290    Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 206289  Data Scientist       Data Scientist- Hybrid Work Location
# 206288    Data Analyst                               Data Analyst
# 206287  Data Scientist            Asset Management Data Scientist
#
#             job_location          job_via job_schedule_type  \
# 206291       Oakland, CA     via Snagajob         Full-time
# 206290          Anywhere     via Snagajob         Full-time
# ...

# %%
# Pivot Table Reset & Set Index
median_salary = df.pivot_table(
    values='salary_year_avg',
    index='job_title_short',
    aggfunc='median'
)
median_salary
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
median_salary.reset_index(inplace=True)
median_salary
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
median_salary.set_index('job_title_short', inplace=True)

# %%
median_salary
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
median_salary.sort_index(inplace=True, ascending=True)
median_salary
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0
