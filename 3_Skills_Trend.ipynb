# %% [markdown]
# ## How are in-demand skills trending for Engineers?
#
# **Methodology**
#
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
# Importing libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ### Group the Skills by Month

# %%
american_countries = [
    'United States', 'Canada', 'Mexico', 'Brazil', 'Argentina', 'Colombia',
    'Chile', 'Peru', 'Venezuela', 'Ecuador', 'Bolivia', 'Paraguay',
    'Uruguay', 'Guyana', 'Suriname', 'Panama', 'Costa Rica', 'Guatemala',
    'Honduras', 'Nicaragua', 'El Salvador', 'Belize', 'Cuba', 'Haiti',
    'Dominican Republic', 'Jamaica', 'Trinidad and Tobago', 'Bahamas'
]

df_america = df[(df['job_title_short'].str.contains('Engineer')) & (df['job_country'].isin(american_countries))].copy()

# %%
df_america['job_posted_month_no'] = df_america['job_posted_date'].dt.month

# %%
df_america_explode = df_america.explode('job_skills')

# %% [markdown]
# ### Pivot in Prep for Plotting

# %%
df_america_pivot = df_america_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

df_america_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month_no
# 1                       1057         2      104      121          12      152
# 2                        909         5      115       91           9      108
# 3                       1007         2       99       81           5      128
# 4                       1020         3       98      107           2      115
# 5                        943         0      104      122           2      112
# 6                       1047         1      145      107           7      125
# 7                        972         7      114      104           1      120
# 8                       1117        21      114      150           2      182
# 9                       1046         4       92      116           3      127
# 10                      1075         6       88      131           6      130
# 11                      1016         7       89      136           4      117
# 12                       994         5       63      139           1       98
#
# job_skills           apl  arch  asana  asp.net  ...  webex  windows  wire  \
# job_posted_month_no                             ...
# 1                      2     1      4       26  ...      1      191     5
# 2                      0     3      7       21  ...      2      167     8
# 3                      2     5      7       19  ...      1      141     4
# 4                      1     2      5       17  ...      1      138     3
# 5                      0     5      5        9  ...      0      137     8
# 6                      1     1      8       21  ...      1      172     7
# 7                      1     3     10       17  ...      6      192    12
# 8                      2    10      6       36  ...      1      256     8
# 9                      0     1      8       22  ...      4      182     4
# 10                     0     3      4       26  ...      2      178     2
# 11                     1     9      2       23  ...      1      200     7
# 12                     3     4      3       27  ...      4      195     9
#
# job_skills           word  workfront  wrike  wsl  xamarin  yarn  zoom
# job_posted_month_no
# 1                     172          0      0    2        3    32    31
# 2                     159          0      0    0        1    41    25
# 3                     165          0      1    1        0    29    13
# 4                     127          0      0    0        0    24    18
# 5                     112          2      0    0        1    33    17
# 6                     126          1      1    0        0    41    28
# 7                     135          2      0    0        4    36    22
# 8                     133          1      0    0        0    41    29
# 9                     163          1      0    0        0    41    16
# 10                    146          0      1    0        0    46    31
# 11                    121          0      0    0        1    28    22
# 12                    119          1      1    0        2    33    31
#
# [12 rows x 241 columns]

# %% [markdown]
# ### Sort columns by count and change month numbers to names

# %%
# sorts by count
df_america_pivot.loc['Total'] = df_america_pivot.sum()
df_america_pivot = df_america_pivot[df_america_pivot.loc['Total'].sort_values(ascending=False).index]
df_america_pivot = df_america_pivot.drop('Total')

df_america_pivot
# Out:
# job_skills           python   sql   aws  azure  spark  java  snowflake  kafka  \
# job_posted_month_no
# 1                      4617  4541  3022   2371   2374  1933       1352   1444
# 2                      4120  4038  2833   1992   2167  1684       1390   1275
# 3                      4288  4277  2932   2074   2133  1615       1329   1214
# 4                      4023  4054  2667   2057   1937  1496       1314   1099
# 5                      3955  3934  2523   1913   1925  1440       1265   1021
# 6                      4240  4436  2742   2138   2134  1534       1363   1148
# 7                      4142  4200  2782   2071   1930  1507       1260   1062
# 8                      5131  5079  3383   2520   2256  1855       1499   1300
# 9                      4501  4439  2823   2148   2035  1483       1319   1059
# 10                     4576  4500  2933   2298   2040  1675       1272   1041
# 11                     4495  4413  2885   2261   2058  1596       1416   1132
# 12                     4144  4095  2664   2139   1906  1603       1304   1061
#
# job_skills           scala  hadoop  ...  fedora  kali  asp.netcore  homebrew  \
# job_posted_month_no                 ...
# 1                     1355    1316  ...       0     0            0         0
# 2                     1225    1257  ...       0     0            0         0
# 3                     1221    1244  ...       0     0            0         0
# 4                     1114    1084  ...       0     0            0         0
# 5                     1063    1021  ...       0     0            1         0
# 6                     1057    1122  ...       0     2            0         0
# 7                     1083    1061  ...       0     0            0         0
# 8                     1258    1214  ...       0     0            1         1
# 9                     1009    1003  ...       0     0            0         0
# 10                    1090    1032  ...       0     0            0         1
# 11                    1046    1034  ...       1     0            0         0
# 12                    1104    1009  ...       1     0            0         0
#
# job_skills           mlr  visualbasic  pascal  tidyr  ocaml  mlpack
# job_posted_month_no
# 1                      0            0       0      0      0       0
# 2                      0            0       0      0      0       0
# 3                      0            0       0      1      0       0
# 4                      0            0       0      0      0       0
# 5                      0            0       0      0      0       0
# 6                      0            0       0      0      0       0
# 7                      0            0       0      0      0       0
# 8                      0            0       0      0      0       0
# 9                      0            0       1      0      0       0
# 10                     1            1       0      0      1       1
# 11                     0            0       0      0      0       0
# 12                     0            0       0      0      0       0
#
# [12 rows x 241 columns]

# %% [markdown]
# ### Plot the Monthly Skill Counts

# %%
df_america_pivot.iloc[:, :5].plot(kind='line')

plt.title('Trending Top Skills for Engineers in America')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Calculate Percentage of Total Jobs

# %%
DE_totals = df_america.groupby('job_posted_month_no').size()

DE_totals
# Out:
# job_posted_month_no
# 1     7736
# 2     6550
# 3     6906
# 4     6663
# 5     6139
# 6     6866
# 7     7154
# 8     8900
# 9     8095
# 10    8344
# 11    7834
# 12    7366
# dtype: int64

# %%
# Divide first 12 rows of df_america_pivot by DE_totals
df_america_percent = df_america_pivot.iloc[:12].div(DE_totals/100, axis=0)

# Changes month number to month name
df_america_percent = df_america_percent.reset_index()
df_america_percent['job_posted_month'] = df_america_percent['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_america_percent = df_america_percent.set_index('job_posted_month')
df_america_percent = df_america_percent.drop(columns='job_posted_month_no')

df_america_percent
# Out:
# job_skills           python        sql        aws      azure      spark  \
# job_posted_month
# Jan               59.682006  58.699586  39.064116  30.648914  30.687694
# Feb               62.900763  61.648855  43.251908  30.412214  33.083969
# Mar               62.090935  61.931654  42.455836  30.031856  30.886186
# Apr               60.378208  60.843464  40.027015  30.871980  29.070989
# May               64.424173  64.082098  41.097899  31.161427  31.356899
# Jun               61.753568  64.608214  39.935916  31.138946  31.080687
# Jul               57.897680  58.708415  38.887336  28.948840  26.977914
# Aug               57.651685  57.067416  38.011236  28.314607  25.348315
# Sep               55.602224  54.836319  34.873379  26.534898  25.138975
# Oct               54.841802  53.930968  35.151007  27.540748  24.448706
# Nov               57.378095  56.331376  36.826653  28.861374  26.270105
# Dec               56.258485  55.593266  36.166169  29.038827  25.875645
#
# job_skills             java  snowflake      kafka      scala     hadoop  ...  \
# job_posted_month                                                         ...
# Jan               24.987073  17.476732  18.665977  17.515512  17.011375  ...
# Feb               25.709924  21.221374  19.465649  18.702290  19.190840  ...
# Mar               23.385462  19.244136  17.578917  17.680278  18.013322  ...
# Apr               22.452349  19.720846  16.494072  16.719196  16.268948  ...
# May               23.456589  20.605962  16.631373  17.315524  16.631373  ...
# Jun               22.341975  19.851442  16.720070  15.394699  16.341392  ...
# Jul               21.065138  17.612524  14.844842  15.138384  14.830864  ...
# Aug               20.842697  16.842697  14.606742  14.134831  13.640449  ...
# Sep               18.319951  16.294009  13.082149  12.464484  12.390364  ...
# Oct               20.074305  15.244487  12.476031  13.063279  12.368169  ...
# Nov               20.372734  18.075057  14.449834  13.352055  13.198877  ...
# Dec               21.762150  17.702960  14.404018  14.987782  13.698072  ...
#
# job_skills          fedora      kali  asp.netcore  homebrew       mlr  \
# job_posted_month
# Jan               0.000000  0.000000     0.000000  0.000000  0.000000
# Feb               0.000000  0.000000     0.000000  0.000000  0.000000
# Mar               0.000000  0.000000     0.000000  0.000000  0.000000
# Apr               0.000000  0.000000     0.000000  0.000000  0.000000
# May               0.000000  0.000000     0.016289  0.000000  0.000000
# Jun               0.000000  0.029129     0.000000  0.000000  0.000000
# Jul               0.000000  0.000000     0.000000  0.000000  0.000000
# Aug               0.000000  0.000000     0.011236  0.011236  0.000000
# Sep               0.000000  0.000000     0.000000  0.000000  0.000000
# Oct               0.000000  0.000000     0.000000  0.011985  0.011985
# Nov               0.012765  0.000000     0.000000  0.000000  0.000000
# Dec               0.013576  0.000000     0.000000  0.000000  0.000000
#
# job_skills        visualbasic    pascal    tidyr     ocaml    mlpack
# job_posted_month
# Jan                  0.000000  0.000000  0.00000  0.000000  0.000000
# Feb                  0.000000  0.000000  0.00000  0.000000  0.000000
# Mar                  0.000000  0.000000  0.01448  0.000000  0.000000
# Apr                  0.000000  0.000000  0.00000  0.000000  0.000000
# May                  0.000000  0.000000  0.00000  0.000000  0.000000
# Jun                  0.000000  0.000000  0.00000  0.000000  0.000000
# Jul                  0.000000  0.000000  0.00000  0.000000  0.000000
# Aug                  0.000000  0.000000  0.00000  0.000000  0.000000
# Sep                  0.000000  0.012353  0.00000  0.000000  0.000000
# Oct                  0.011985  0.000000  0.00000  0.011985  0.011985
# Nov                  0.000000  0.000000  0.00000  0.000000  0.000000
# Dec                  0.000000  0.000000  0.00000  0.000000  0.000000
#
# [12 rows x 241 columns]

# %% [markdown]
# ### Plot Mothly Skill Demand

# %%
from matplotlib.ticker import PercentFormatter

df_plot = df_america_percent.iloc[:, :5]
sns.lineplot(data=df_plot, dashes=False, legend='full', palette='tab10')
sns.set_theme(style='ticks')
sns.despine()

plt.title('Trending Top Skills for Engineers in America')
plt.ylabel('Likelihood in Job Posting')
plt.xlabel('2023')
plt.legend().remove()
plt.gca().yaxis.set_major_formatter(PercentFormatter(decimals=0))

for i in range(5):
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i], color='black')

plt.show()
